# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidence to answer the following questions.
#
# 1. How many neighborhood groups are there and which shows up the most?
# 2. Are private rooms the most popular in Manhattan?
# 3. Who are the top 10 busiest hosts based on number of reviews per month?
# 4. Which neighorhood group has the highest average price? Plot the average prices in a professional looking bar chart
# 5. What is the most expensive neighbourhood in each neighbourhood group?
# 6. Which host has the highest minimum rental? *minimal rental is based on price and minimum nights
# 7. Who currently has no (zero) availability with a review count of 100 or more?
# 8. If each host rents all of their properties for the night, which 5 make the most that night?
# 9. When did Danielle from Queens last receive a review?
# 10. Display a bar chart showing the number of each type of room in the Bronx
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this entire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to simulate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ab = pd.read_csv('./AB_NYC_2019.csv')
ab.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# What is the most expensive neighbourhood in each neighbourhood_group
# 'Brooklyn'- Greenpoint 'Manhattan'-Upper West Side 'Queens'-Astoria 'Staten Island'-Randall Manor 'Bronx'-Riverdale 

#ng = ab.groupby(['neighbourhood_group']).max([['price']])#[['neighbourhood_group','neighbourhood','price']]
ng = ab.groupby(['neighbourhood_group'], sort=False)['price'].max()
idx = ab.groupby(['neighbourhood_group'])['price'].transform(max) == ab['price']


print(ng)
print(ab[idx])
# Out:
# neighbourhood_group
# Brooklyn         10000
# Manhattan        10000
# Queens           10000
# Staten Island     5000
# Bronx             2500
# Name: price, dtype: int64
#              id                                             name    host_id  \
# 9151    7003697              Furnished room in Astoria apartment   20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 22353  18051877                          Victorian Film location    2675644
# 24477  19698169                          "The luxury of Comfort"  131826530
# 29238  22436899                              1-BR Lincoln Center   72390391
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 22353    Alissa       Staten Island    Randall Manor  40.63952  -74.09730
# ...

# %%
# When did Danielle from Queens last receive a review?
# 2019-07-06
new = ab[(ab['host_name']=='Danielle') & (ab['neighbourhood_group']=='Brooklyn')].sort_values('last_review', ascending =False)['last_review']
print(new)
# Out:
# 29546    2019-07-06
# 5717     2019-07-06
# 3062     2019-06-25
# 24499    2019-06-23
# 12519    2019-06-23
# 46507    2019-06-18
# 8166     2019-06-16
# 11008    2019-06-13
# 12412    2019-06-09
# 5495     2019-05-26
# 8219     2019-05-24
# 22133    2019-05-19
# 555      2019-04-30
# 20928    2019-01-01
# 25082    2018-12-08
# 21260    2018-10-24
# 2902     2018-10-18
# 31724    2018-05-15
# 11547    2017-12-03
# 24928    2017-08-05
# 6143     2017-06-27
# 20149    2017-01-04
# 13106    2016-10-16
# 11842    2016-07-23
# 12305    2016-06-20
# 4687            NaN
# 7397            NaN
# 14239           NaN
# 15654           NaN
# 37221           NaN
# 43825           NaN
# Name: last_review, dtype: object

# %%
 #ab.loc([ab['number_of_reviews']>100], ascending=True)#over 100 reviews
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-73dbb563c588> in <module>
# ----> 1 ab.loc([ab['number_of_reviews']>100], ascending=True)#over 100 reviews
#
# TypeError: __call__() got an unexpected keyword argument 'ascending'

# %%
# Who has no (zero) availability with a review count of 100 or more
Many - 148 rows x 9 columns

ab_new = ab[(ab['number_of_reviews'] >=100) & (ab['availability_365'] == 0)].groupby('host_id').sum()
print(ab_new)
# Out:
#                  id  latitude  longitude  price  minimum_nights  \
# host_id
# 7490           5203  40.80178  -73.96723     79               2
# 36897        282443  40.71601  -73.99123     90               3
# 67778         45556  40.68863  -73.97691     65               2
# 79402         20913  40.70984  -73.95775    100               5
# 116382     11684682  40.67031  -73.94088     29               2
# ...             ...       ...        ...    ...             ...
# 142878742  20092506  40.79074  -73.94232     70               1
# 143944704  20332555  40.76302  -73.98211    239               3
# 159156636  21901156  40.75656  -73.99063    120               1
# 176185168  23574142  40.68209  -73.73662     65               1
# 209549523  27759146  40.74858  -73.98341     62               1
#
#            number_of_reviews  reviews_per_month  \
# host_id
# 7490                     118               0.99
# 36897                    107               1.17
# ...

# %%
# new = ab[['availability_365','host_name','number_of_reviews']]
# #zero availability with over 100 reviews
# idx1 = ab.groupby(['availability_365'])['number_of_reviews'].transform(max) == ab['number_of_reviews']

# print(new)
# print(ab[idx1])


# ng = ab.groupby(['neighbourhood_group'], sort=False)['price'].max()
# idx = ab.groupby(['neighbourhood_group'])['price'].transform(max) == ab['price']


# print(ng)
# print(ab[idx])
# Out:
#        availability_365      host_name  number_of_reviews
# 0                   365           John                  9
# 1                   355       Jennifer                 45
# 2                   365      Elisabeth                  0
# 3                   194    LisaRoxanne                270
# 4                     0          Laura                  9
# ...                 ...            ...                ...
# 48890                 9        Sabrina                  0
# 48891                36        Marisol                  0
# 48892                27  Ilgar & Aysel                  0
# 48893                 2            Taz                  0
# 48894                23     Christophe                  0
#
# [48895 rows x 3 columns]
#              id                                               name    host_id  \
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 7          5178                   Large Furnished Room Near B'way        8967
# ...

# %%
print(ab[['neighbourhood_group']])

# ab['total']=ab['neighbourhood_group']
# ab
# Out:
#       neighbourhood_group
# 0                Brooklyn
# 1               Manhattan
# 2               Manhattan
# 3                Brooklyn
# 4               Manhattan
# ...                   ...
# 48890            Brooklyn
# 48891            Brooklyn
# 48892           Manhattan
# 48893           Manhattan
# 48894           Manhattan
#
# [48895 rows x 1 columns]

# %%
 ab.loc[ab['neighbourhood_group']=="Queens"]
# Out:
#              id                                               name    host_id  \
# 46        12937  1 Stop fr. Manhattan! Private Suite,Landmark B...      50124
# 77        18198                              Little King of Queens      70091
# 143       32363                 Fully Furnished Basement Apartment     140025
# 161       39593            A room w/ a Manhattan view, longer stay     110506
# 181       45910                 Beautiful Queens Brownstone! - 5BR     204539
# ...         ...                                                ...        ...
# 48858  36458668  2beds Private Room Step to LGA, CitiFiled, Mid...  217463199
# 48863  36469741                Comfortable & Big room with 2 beds!  274012871
# 48866  36472710                                 CozyHideAway Suite  274225617
# 48878  36479723                                      Room for rest   41326856
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
#
# ...

# %%
ab.loc[ab['neighbourhood_group']=="Manhattan"]
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# ...         ...                                                ...        ...
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
 ab.loc[ab['neighbourhood_group']=="Brooklyn"]
# Out:
#              id                                             name    host_id  \
# 0          2539               Clean & quiet apt home by the park       2787
# 3          3831                  Cozy Entire Floor of Brownstone       4869
# 6          5121                                  BlissArtsSpace!       7356
# 12         5803   Lovely Room 1, Garden, Best Area, Legal rental       9744
# 15         6848                 Only 2 stops to Manhattan studio      15991
# ...         ...                                              ...        ...
# 48882  36482231                        Bushwick _ Myrtle-Wyckoff   66058896
# 48884  36482783      Brooklyn Oasis in the heart of Williamsburg  274307600
# 48887  36483152  Garden Jewel Apartment in Williamsburg New York  208514239
# 48890  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057    Affordable room in Bushwick/East Williamsburg    6570630
#
# ...

# %%
ab.groupby(['room_type'])
ab['count']=1

# ab.groupby(['year']).count()['count']

# %%
ab.groupby('neighbourhood_group', as_index=False).count()
# Out:
#   neighbourhood_group     id   name  host_id  host_name  neighbourhood  \
# 0               Bronx   1091   1090     1091       1090           1091
# 1            Brooklyn  20104  20098    20104      20095          20104
# 2           Manhattan  21661  21652    21661      21652          21661
# 3              Queens   5666   5666     5666       5664           5666
# 4       Staten Island    373    373      373        373            373
#
#    latitude  longitude  room_type  price  minimum_nights  number_of_reviews  \
# 0      1091       1091       1091   1091            1091               1091
# 1     20104      20104      20104  20104           20104              20104
# 2     21661      21661      21661  21661           21661              21661
# 3      5666       5666       5666   5666            5666               5666
# 4       373        373        373    373             373                373
#
#    last_review  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
# How many neighbourhood groups / which shows up the most
Bronx, Brooklyn,Manhattan,Queens,Staten Island - 5/ Manhattan

# %%
ab.loc[ab['neighbourhood_group'].str.contains('Manhattan')]
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# ...         ...                                                ...        ...
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
# Are private rooms the most popular in Manhattan?
# No, entire homes are.

ab.groupby(['room_type','neighbourhood_group']).count()
# Entire - 13199
# Private - 7982
# Shared - 480
# Out:
#                                         id   name  host_id  host_name  \
# room_type       neighbourhood_group
# Entire home/apt Bronx                  379    379      379        378
#                 Brooklyn              9559   9558     9559       9554
#                 Manhattan            13199  13193    13199      13196
#                 Queens                2096   2096     2096       2096
#                 Staten Island          176    176      176        176
# Private room    Bronx                  652    652      652        652
#                 Brooklyn             10132  10127    10132      10128
#                 Manhattan             7982   7979     7982       7976
#                 Queens                3372   3372     3372       3370
#                 Staten Island          188    188      188        188
# Shared room     Bronx                   60     59       60         60
#                 Brooklyn               413    413      413        413
# ...

# %%
# ab.groupby(['room_type']).mean()
ab

# %%
ab.groupby(['reviews_per_month','host_name']).count().sort_values('reviews_per_month', ascending=False)
# Out:
#                              id  name  host_id  neighbourhood_group  \
# reviews_per_month host_name
# 58.50             Row NYC     1     1        1                    1
# 27.95             Row NYC     1     1        1                    1
# 20.94             Louann      1     1        1                    1
# 19.75             Nalicia     1     1        1                    1
# 17.82             Nalicia     1     1        1                    1
# ...                          ..   ...      ...                  ...
# 0.01              Mark        2     2        2                    2
#                   Maria       1     1        1                    1
#                   Lisa        1     1        1                    1
#                   Lauren      1     1        1                    1
#                   Aaron       1     1        1                    1
#
#                              neighbourhood  latitude  longitude  room_type  \
# reviews_per_month host_name
# ...

# %%
print(ab['host_name'][0:10])
# Out:
# 0           John
# 1       Jennifer
# 2      Elisabeth
# 3    LisaRoxanne
# 4          Laura
# 5          Chris
# 6          Garon
# 7       Shunichi
# 8      MaryEllen
# 9            Ben
# Name: host_name, dtype: object

# %%
print(ab['reviews_per_month'][0:10])
# Out:
# 0    0.21
# 1    0.38
# 2     NaN
# 3    4.64
# 4    0.10
# 5    0.59
# 6    0.40
# 7    3.47
# 8    0.99
# 9    1.33
# Name: reviews_per_month, dtype: float64

# %%
print(ab)

# %%
print(ab.nlargest(19, 'reviews_per_month'))
# Out:
#              id                                               name    host_id  \
# 42075  32678719  Enjoy great views of the City in our Deluxe Room!  244361589
# 42076  32678720           Great Room in the heart of Times Square!  244361589
# 38870  30423106                 Lou's Palace-So much for so little  228415932
# 27287  21550302  JFK Comfort.5 Mins from JFK Private Bedroom & ...  156684502
# 28651  22176831      JFK 2 Comfort 5 Mins from JFK Private Bedroom  156684502
# 29628  22750161      JFK 3 Comfort 5 Mins from JFK Private Bedroom  156684502
# 20403  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE   26432133
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE   26432133
# 36238  28826608                                 “For Heaven Cakes”  217379941
# 40297  31249784        Studio Apartment 6 minutes from JFK Airport  232251881
# 40036  31090222            6 Minutes From JFK Airport Cozy Bedroom  232251881
# ...

# %%
ng = ab.groupby('neighbourhood')

print(ng['neighbourhood'].head(10))
# Out:
# 0          Kensington
# 1             Midtown
# 2              Harlem
# 3        Clinton Hill
# 4         East Harlem
#              ...
# 48633     Castle Hill
# 48649     Shore Acres
# 48699        Sea Gate
# 48751    Breezy Point
# 48799     Great Kills
# Name: neighbourhood, Length: 1932, dtype: object

# %%
h_price = ab.groupby('neighbourhood')['price'].agg(np.mean)
print(h_price.nlargest(20))
# Out:
# neighbourhood
# Fort Wadsworth        800.000000
# Woodrow               700.000000
# Tribeca               490.638418
# Sea Gate              487.857143
# Riverdale             442.090909
# Prince's Bay          409.500000
# Battery Park City     367.557143
# Flatiron District     341.925000
# Randall Manor         336.000000
# NoHo                  295.717949
# SoHo                  287.103352
# Midtown               282.719094
# Neponsit              274.666667
# West Village          267.682292
# Greenwich Village     263.405612
# Chelsea               249.738544
# Willowbrook           249.000000
# Theater District      248.013889
# Nolita                230.138340
# Financial District    225.490591
# Name: price, dtype: float64

# %%
# How many neighbourhood groups / which shows up the most
Bronx, Brooklyn,Manhattan,Queens,Staten Island - 5/ Manhattan


# print(ab[['neighbourhood_group']])
# for index, row in ab.iterrows():
#     print(index,row['neighbourhood_group'])
for col in ab:
  print(ab['neighbourhood_group'].unique())
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']

# %%
sorted_data = ab.sort_values('neighbourhood_group', kind='quick')

sorted_data.reset_index(drop=True)
# Out:
#              id                                               name    host_id  \
# 0       5824543  Private room for 2 (10 min to city) - Females ...   30232055
# 1      34756976                                        Gigi’s Room   74633496
# 2      25833266             Huge private & cozy room in the Bronx!  194102474
# 3      19974905                                     Esteem's Place  141615596
# 4      25816034     Bronx 2 Bedroom with View of Manhattan Skyline  179677211
# ...         ...                                                ...        ...
# 48890  18997371                                       Cozy Getaway   90104417
# 48891  33804180  Cozy farmhouse in NYC. 2 bdrms; 2 full baths. ...  163169045
# 48892  34945914                              "Dave's Island Suite"  258232863
# 48893   8387338                  Private Room Available in 2BedApt   44195923
# 48894  15833574                       Delightful studio apartment.  102526590
#
# ...

# %%
avg_price = ab.groupby('neighbourhood_group')['price'].agg(np.mean)
print(avg_price.nlargest(10))
# Out:
# neighbourhood_group
# Manhattan        196.875814
# Brooklyn         124.383207
# Staten Island    114.812332
# Queens            99.517649
# Bronx             87.496792
# Name: price, dtype: float64

# %%
avg_price = ab.groupby('neighbourhood')['price'].agg(np.mean)
print(avg_price.nlargest(10))
# Out:
# neighbourhood
# Fort Wadsworth       800.000000
# Woodrow              700.000000
# Tribeca              490.638418
# Sea Gate             487.857143
# Riverdale            442.090909
# Prince's Bay         409.500000
# Battery Park City    367.557143
# Flatiron District    341.925000
# Randall Manor        336.000000
# NoHo                 295.717949
# Name: price, dtype: float64

# %%
avg_price = ab.groupby('neighbourhood')['price'].agg(np.mean)
print(avg_price)
# Out:
# neighbourhood
# Allerton            87.595238
# Arden Heights       67.250000
# Arrochar           115.000000
# Arverne            171.779221
# Astoria            117.187778
#                       ...
# Windsor Terrace    138.993631
# Woodhaven           67.170455
# Woodlawn            60.090909
# Woodrow            700.000000
# Woodside            85.097872
# Name: price, Length: 221, dtype: float64

# %%
avg_price = ab.groupby('neighbourhood_group')['price'].agg(np.mean)
print(avg_price)
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
ab.groupby('price').mean()
# ab['price'].mean()
# Out:
#                  id       host_id   latitude  longitude  minimum_nights  \
# price
# 0      2.057179e+07  5.862573e+07  40.712058 -73.925670        7.363636
# 10     2.235300e+07  9.768142e+07  40.729329 -73.936397        4.058824
# 11     2.647160e+07  1.051506e+08  40.738027 -73.925720        3.333333
# 12     2.410396e+07  2.886539e+07  40.714980 -73.970377       76.750000
# 13     3.487058e+07  1.581790e+08  40.631360 -74.125590        1.000000
# ...             ...           ...        ...        ...             ...
# 7703   2.277973e+07  1.561588e+08  40.768240 -73.959890        1.000000
# 8000   2.953058e+06  1.177497e+06  40.691370 -73.967230        1.000000
# 8500   2.337741e+07  1.812846e+07  40.721970 -74.006330       30.000000
# 9999   1.520238e+07  3.174554e+06  40.741997 -73.969903       44.666667
# 10000  1.444498e+07  3.270571e+07  40.757610 -73.953517       45.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# price
# ...

# %%
print(ab.nlargest(19, 'price'))#Highest prices
# Out:
#              id                                               name    host_id  \
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 29238  22436899                                1-BR Lincoln Center   72390391
# 6530    4737930                                 Spanish Harlem Apt    1235070
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 30268  23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# 4377    2953058                                      Film Location    1177497
# 29662  22779726          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 42523  33007610                70' Luxury MotorYacht on the Hudson    7407743
# 45666  34895693                               Gem of east Flatbush  262534951
# ...

# %%
# for ab in pd.read_csv('modified.csv',chunksize=25):
#     print("Chunk ab")
   
 ab.head(5)
# Out:
#   File "<ipython-input-38-df3c8ce8cfc8>", line 4
#     ab.head(5)
#     ^
# IndentationError: unexpected indent

# %%
# ab['count']=1
# ab.groupby(['neighbourhood_group','room_type']).count()['count']
# ab
# df= pd.read_csv('modified.csv')
# ab['count']=1

# ab.groupby(['neighbourhood_group','room_type'])


ab.groupby(['neighbourhood_group']).mean()
# Out:
#                                id       host_id   latitude  longitude  \
# neighbourhood_group
# Bronx                2.273492e+07  1.056099e+08  40.848305 -73.884552
# Brooklyn             1.825685e+07  5.671526e+07  40.685036 -73.951190
# Manhattan            1.877494e+07  6.783062e+07  40.765062 -73.974607
# Queens               2.175500e+07  9.615680e+07  40.731531 -73.872775
# Staten Island        2.159747e+07  9.853360e+07  40.610225 -74.105805
#
#                           price  minimum_nights  number_of_reviews  \
# neighbourhood_group
# Bronx                 87.496792        4.560953          26.004583
# Brooklyn             124.383207        6.056556          24.202845
# Manhattan            196.875814        8.579151          20.985596
# Queens                99.517649        5.181433          27.700318
# Staten Island        114.812332        4.831099          30.941019
#
#                      reviews_per_month  calculated_host_listings_count  \
# neighbourhood_group
# ...

# %%
# ab=ab.read_csv('./AB_NYC_2019.csv')
# ab['count']=1
# ab.groupby(['neighbourhood_group','room_type'])['count']

# %%
# If each host rents all of their properties for the night, which 5 make the most that night?
# Katherine, Erin, Jalena, Olsen, Amy

new1 = ab.groupby(['host_name'])['price'].sum()
print(new1)
print(ab.nlargest(5, 'price'))
# Out:
# host_name
# 'Cil                         120
# (Ari) HENRY LEE              140
# (Email hidden by Airbnb)    1060
# (Mary) Haiy                  126
# -TheQueensCornerLot          150
#                             ...
# 단비                           150
# 빈나                           125
# 소정                           103
# 진                             70
# 현선                          1200
# Name: price, Length: 11452, dtype: int64
#              id                                             name   host_id  \
# 9151    7003697              Furnished room in Astoria apartment  20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                              1-BR Lincoln Center  72390391
# 6530    4737930                               Spanish Harlem Apt   1235070
# 12342   9528920              Quiet, Clean, Lit @ LES & Chinatown   3906464
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# ...

# %%
# Which host has the highest minimum rental? *minimal rental is based on price and minimum nights

# jessica
ab[['host_name','minimum_nights','price']].nlargest(20, ['price']).sort_values('minimum_nights').head(10)
# Out:
#       host_name  minimum_nights  price
# 42523      Jack               1   7500
# 15560     Linda               1   6000
# 29664     Sally               1   6419
# 4377    Jessica               1   8000
# 29662     Sally               1   7703
# 3720       Omri               1   5250
# 45666    Sandra               1   7500
# 44034     Kevin               1   6800
# 3774   Jonathan               1   6500
# 17692      Erin               5  10000

# %%
# How many neighbourhood groups / which shows up the most
Bronx, Brooklyn,Manhattan,Queens,Staten Island - 5/ Manhattan

# %%
# Are private rooms the most popular in Manhattan?
No, entire homes are.

# %%
# Who are the top 10 busiest hosts based on number of reviews per month?
Row NYC,Louann,Nalicia,Danielle,Brent,Lakshmee,Dona,Alina,Sam,Yvonne

# %%
# Which neighborhood group has the highest avg price and plot the average prices in a bar chart
Manhattan

# %%
# What is the most expensive neighbourhood in each neighbourhood_group
'Brooklyn'- Greenpoint 'Manhattan'-Upper West Side 'Queens'-Astoria 'Staten Island'-Randall Manor 'Bronx'-Riverdale

# %%
# Which host has the highest minimum rental? *minimal rental is based on price and minimum nights
Jessica

# %%
# Who has no (zero) availability with a review count of 100 or more
see above

# %%
# If each host rents all of their properties for the night, which 5 make the most that night?
Katherine, Erin, Jalena, Olsen, Amy

# %%
# When did Danielle from Queens last receive a review?
2019-07-06

# %%
# bar chart showing the number of room types in the Bronx

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
